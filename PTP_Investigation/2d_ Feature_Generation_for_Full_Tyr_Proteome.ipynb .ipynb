# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import MACCSkeys
from rdkit.Chem import rdmolfiles
import itertools
from collections import Counter

# %%
# Import file containing peptide sequences, protein information, and experimental values
#  for the different 15 enzymes analysed within the investigation
peptides = pd.read_csv('./Full_Tyr_Proteome_MSD_Scores_13_mer.csv', index_col=0)

# %%
peptides
# Out:
#            uid_pos Uniprot_ID Central_AA  Position  Netsurfp_RSA  \
# 0        Q99871_15     Q99871          Y        15      0.565898
# 1        Q99871_47     Q99871          Y        47      0.570332
# 2        Q99871_64     Q99871          Y        64      0.322800
# 3        Q99873_52     Q99873          Y        52      0.309666
# 4       Q99873_125     Q99873          Y       125      0.434846
# ...            ...        ...        ...       ...           ...
# 177255  P0DJX6_117     P0DJX6          Y       117      0.374022
# 177256  P0DJX7_117     P0DJX7          Y       117      0.374022
# 177257   P0DSS1_68     P0DSS1          Y        68      0.310163
# 177258   P0DSS2_68     P0DSS2          Y        68      0.310163
# 177259   P0DTB5_56     P0DTB5          Y        56      0.418697
#
#               Peptide      Gene_ID   Padding  SECONDARY_ML_SCORE
# 0       GRGGDDYSEDEGD  HAUS7_HUMAN       NaN               0.867
# 1       PFLEGLYITEPKT  HAUS7_HUMAN       NaN               0.079
# 2       LCSPSEYRLEILE  HAUS7_HUMAN       NaN               0.051
# 3       DMTSKDYYFDSYA   ANM1_HUMAN       NaN               0.092
# 4       CSSISDYAVKIVK   ANM1_HUMAN       NaN               0.061
# ...               ...          ...       ...                 ...
# 177255  IDGRRDYKPDKSA  ALT2B_EMCVR  A to end               0.344
# 177256  IDGRRDYKPDKSA   ALT2B_EMCV  A to end               0.344
# 177257  PGTIILYATYIKA  PG081_VAR67  A to end               0.065
# 177258  PGTIILYATYIKA   PG081_VARV  A to end               0.065
# 177259  AKWELKYQRKRLA  ORF2P_CXB3N  A to end               0.192
#
# [177260 rows x 9 columns]

# %%
# Import file containing protdcal values (needed for feature generation later on)
protdcal = pd.read_csv('../protdcal_features.csv', index_col=0)

# %%
## NOW WE CAN GO ON TO GENERATING OUR FEATURES ##

# %%
# METHOD FOR GENERATING FEATURES USING ONE SEQUENCE AT A TIME
def FeatureGen (sequence, protdcal):
    # FIRST: GENERATE PROTDCAL VALUES
    slist = list(sequence)   # first split sequence up into list
    # Go through sequence to get protdcal value
    pd = []
    for i in slist:
        pd.append(protdcal.loc[i].tolist())
    values = list(map(lambda *x: sum(x), *pd))   # add up values
    headers =  protdcal.columns.tolist()   # include headers


    # SECOND: GENERATE ONE-HOT ENCODING
    aa = ['K', 'R', 'H', 'A', 'I', 'L', 'M', 'V', 'F', 'W', 'Y', 'N', 'C', 'Q', 'S', 'T', 'D', 'E', 'G', 'P']   # possible amino acids
    # Make headers and one-hot encoding for each letter
    for i in aa:
        j = 0
        while j < len(sequence):
            headers.append('ONE-HOT_' + str(j) + '-' + i)  # make header
            if sequence[j] == i:
                values.append(1)
            else:
                values.append(0)
            j+=1


    # THIRD: GENERATE MACCS KEYS
    # Generate maccs keys
    mol = (rdmolfiles.MolFromFASTA(sequence))
    fp = (MACCSkeys.GenMACCSKeys(mol))
    maccs = fp.ToBitString()
    binary = list(maccs)   # split up into list
    values.extend(binary)   # add list onto resulting values
    # Generate headers for maccs keys
    mt = list(itertools.chain(range(len(binary))))
    mt = [str(s) + '_maccs' for s in mt]
    headers.extend(mt)   # append header values

    return values, headers

# %%
peptides = peptides.set_index('uid_pos', drop=True)

# %%
peptides[peptides['Peptide'].str.contains('X')]
# Out:
#             uid_pos Uniprot_ID Central_AA  Position  Netsurfp_RSA  \
# 22771    Q9WSV7_330     Q9WSV7          Y       330      0.306006
# 56584    P13890_205     P13890          Y       205      0.288540
# 56586    P13890_444     P13890          Y       444      0.260461
# 56607   P13896_1855     P13896          Y      1855      0.253373
# 69785   Q9YLR1_1575     Q9YLR1          Y      1575      0.363802
# 72195    P03441_351     P03441          Y       351      0.275370
# 72201    P03441_511     P03441          Y       511      0.409480
# 87316    Q9WC70_133     Q9WC70          Y       133      0.252874
# 100227    P17517_15     P17517          Y        15      0.302336
# 100985    P26028_36     P26028          Y        36      0.596960
# 118094   Q703F0_383     Q703F0          Y       383      0.358324
# 139147    Q96831_22     Q96831          Y        22      0.447399
# 139150   Q96831_173     Q96831          Y       173      0.319979
# 160133  Q306W6_1859     Q306W6          Y      1859      0.268062
# 160161  Q306W8_1862     Q306W8          Y      1862      0.267371
# 168766   P87515_598     P87515          Y       598      0.345663
# 169876   Q9IDV7_135     Q9IDV7          Y       135      0.284907
#
#               Peptide      Gene_ID Padding  SECONDARY_ML_SCORE
# 22771   GSNTXDYMSPXIS  CAPSD_TTVV5     NaN               0.625
# 56584   HHGAVQYSXGRFT    POLS_RRVN     NaN               0.048
# 56586   HCPPGDYLKXSFE    POLS_RRVN     NaN               0.097
# 56607   QHSNXRYEAGAYI    POLN_WEEV     NaN               0.106
# 69785   VVLCSDYRQXRNA   POLN_HEVUS     NaN               0.060
# 72195   GMXXGWYGFRHQN   HEMA_I79A0     NaN               0.060
# 72201   VELKXGYKDWILW   HEMA_I79A0     NaN               0.052
# 87316   PGPGTXYPLTFGW    NEF_HV1S9     NaN               0.037
# 100227  YKATRPYXXXCAD    POLS_RRV2     NaN               0.032
# 100985  XXXXRPYVLLAVL   HEMA_MEASI     NaN               0.036
# 118094  ISTAAXYRNAVVE     GE_HHV1F     NaN               0.044
# 139147  RAPSKMYGGAXQR     NP_ADE04     NaN               0.126
# 139150  PRRGNVYWVRDXA     NP_ADE04     NaN               0.249
# 160133  RHSNXRYEAGAYI   POLN_EEEV1     NaN               0.133
# 160161  RHSNXRYEAGAYI   POLN_EEEV8     NaN               0.133
# 168766  RYAVDKYXGRVLV     POLN_BFV     NaN               0.050
# 169876  VLPRCXYPAGHXQ    VIF_HV1YB     NaN               0.094

# %%
# Pull sequences and make X -> A for feature generation (A is least offensive AA)
sequences = peptides['Peptide'].str.replace('X', 'A')

# %%
## GENERATE FEATURES FOR OUR EXPERIMENTAL DATA
# Create df for results to go into
v, h = FeatureGen(sequences[0], protdcal)
features = pd.DataFrame(columns=h)
features.loc[len(features)] = v

i = 1

# Go through rest of sequences to generate feature set
while i < len(sequences):
    ts = sequences[i]
    value, header = FeatureGen(ts, protdcal)
    features.loc[len(features)] = value
    i+=1
    if i % 500 == 0:
        print(i, 'of', len(sequences), 'completed')

# Make the index the same as our initial dataframe
feat_x = features.set_index(peptides.index)

# Isolate the methylated condition from the sequences as our y value
#feat_y = peptides['Experimental_Phosphorylation']
# Out:
# 500 of 177260 completed
# 1000 of 177260 completed
# 1500 of 177260 completed
# 2000 of 177260 completed
# 2500 of 177260 completed
# 3000 of 177260 completed
# 3500 of 177260 completed
# 4000 of 177260 completed
# 4500 of 177260 completed
# 5000 of 177260 completed
# 5500 of 177260 completed
# 6000 of 177260 completed
# 6500 of 177260 completed
# 7000 of 177260 completed
# 7500 of 177260 completed
# 8000 of 177260 completed
# 8500 of 177260 completed
# 9000 of 177260 completed
# 9500 of 177260 completed
# 10000 of 177260 completed
# 10500 of 177260 completed
# 11000 of 177260 completed
# 11500 of 177260 completed
# 12000 of 177260 completed
# 12500 of 177260 completed
# 13000 of 177260 completed
# 13500 of 177260 completed
# 14000 of 177260 completed
# 14500 of 177260 completed
# 15000 of 177260 completed
# 15500 of 177260 completed
# 16000 of 177260 completed
# 16500 of 177260 completed
# 17000 of 177260 completed
# 17500 of 177260 completed
# 18000 of 177260 completed
# 18500 of 177260 completed
# 19000 of 177260 completed
# 19500 of 177260 completed
# 20000 of 177260 completed
# 20500 of 177260 completed
# 21000 of 177260 completed
# 21500 of 177260 completed
# 22000 of 177260 completed
# 22500 of 177260 completed
# 23000 of 177260 completed
# 23500 of 177260 completed
# 24000 of 177260 completed
# 24500 of 177260 completed
# 25000 of 177260 completed
# 25500 of 177260 completed
# 26000 of 177260 completed
# 26500 of 177260 completed
# 27000 of 177260 completed
# 27500 of 177260 completed
# 28000 of 177260 completed
# 28500 of 177260 completed
# 29000 of 177260 completed
# 29500 of 177260 completed
# 30000 of 177260 completed
# 30500 of 177260 completed
# 31000 of 177260 completed
# 31500 of 177260 completed
# 32000 of 177260 completed
# 32500 of 177260 completed
# 33000 of 177260 completed
# 33500 of 177260 completed
# 34000 of 177260 completed
# 34500 of 177260 completed
# 35000 of 177260 completed
# 35500 of 177260 completed
# 36000 of 177260 completed
# 36500 of 177260 completed
# 37000 of 177260 completed
# 37500 of 177260 completed
# 38000 of 177260 completed
# 38500 of 177260 completed
# 39000 of 177260 completed
# 39500 of 177260 completed
# 40000 of 177260 completed
# 40500 of 177260 completed
# 41000 of 177260 completed
# 41500 of 177260 completed
# 42000 of 177260 completed
# 42500 of 177260 completed
# 43000 of 177260 completed
# 43500 of 177260 completed
# 44000 of 177260 completed
# 44500 of 177260 completed
# 45000 of 177260 completed
# 45500 of 177260 completed
# 46000 of 177260 completed
# 46500 of 177260 completed
# 47000 of 177260 completed
# 47500 of 177260 completed
# 48000 of 177260 completed
# 48500 of 177260 completed
# 166000 of 177260 completed
# 166500 of 177260 completed
# 167000 of 177260 completed
# 167500 of 177260 completed
# 168000 of 177260 completed
# 168500 of 177260 completed
# 169000 of 177260 completed
# 169500 of 177260 completed
# 170000 of 177260 completed
# 170500 of 177260 completed
# 171000 of 177260 completed
# 171500 of 177260 completed
# 172000 of 177260 completed
# 172500 of 177260 completed
# 173000 of 177260 completed
# 173500 of 177260 completed
# 174000 of 177260 completed
# 174500 of 177260 completed
# 175000 of 177260 completed
# 175500 of 177260 completed
# 176000 of 177260 completed
# 176500 of 177260 completed
# 177000 of 177260 completed

# %%
feat_x.to_csv('./Full_Proteome_Exp_Set/full_proteome_tyr_peps_13mer_features.csv')
#feat_y.to_csv('./features/palma_2017_y_features.csv')
peptides.to_csv('./Full_Proteome_Exp_Set/full_proteome_tyr_peps_13mer_details.csv')

# %%
peptides.head()
# Out:
#            Uniprot_ID Central_AA  Position  Netsurfp_RSA        Peptide  \
# uid_pos
# Q99871_15      Q99871          Y        15      0.565898  GRGGDDYSEDEGD
# Q99871_47      Q99871          Y        47      0.570332  PFLEGLYITEPKT
# Q99871_64      Q99871          Y        64      0.322800  LCSPSEYRLEILE
# Q99873_52      Q99873          Y        52      0.309666  DMTSKDYYFDSYA
# Q99873_125     Q99873          Y       125      0.434846  CSSISDYAVKIVK
#
#                 Gene_ID Padding  SECONDARY_ML_SCORE
# uid_pos
# Q99871_15   HAUS7_HUMAN     NaN               0.867
# Q99871_47   HAUS7_HUMAN     NaN               0.079
# Q99871_64   HAUS7_HUMAN     NaN               0.051
# Q99873_52    ANM1_HUMAN     NaN               0.092
# Q99873_125   ANM1_HUMAN     NaN               0.061

# %%
feat_x.head()
# Out:
#             Gs(U)_NO   Mw_NO  HP_NO  IP_NO  ECI_NO  L1-9_NO   DHf_NO  Z1_NO  \
# uid_pos
# Q99871_15  -4603.390  1352.0  -29.2  68.36   10.77   234.67 -6148.50  31.29
# Q99871_47   -207.748  1488.0   -2.3  80.83    5.86   232.28 -5911.19 -10.30
# Q99871_64   -342.718  1532.0   -1.1  80.24    8.04   235.50 -6046.04  -5.57
# Q99873_52  -2192.715  1586.0  -14.1  69.49    8.74   227.91 -6028.87   7.09
# Q99873_125   631.851  1393.0    6.7  80.01    5.23   240.14 -5924.10   0.33
#
#             Z2_NO  Z3_NO  ...  157_maccs  158_maccs  159_maccs  160_maccs  \
# uid_pos                   ...
# Q99871_15  -12.65   5.50  ...          1          1          1          0
# Q99871_47   -5.43  -5.99  ...          1          1          1          1
# Q99871_64   -1.69  -3.32  ...          1          1          1          1
# Q99873_52    5.71   3.84  ...          1          1          1          1
# Q99873_125  -9.74  -2.62  ...          1          1          1          1
#
#             161_maccs  162_maccs  163_maccs  164_maccs  165_maccs  166_maccs
# uid_pos
# Q99871_15           1          1          1          1          1          0
# Q99871_47           1          1          1          1          1          0
# Q99871_64           1          1          1          1          1          0
# Q99873_52           1          1          1          1          1          0
# Q99873_125          1          1          1          1          1          0
#
# [5 rows x 443 columns]
